# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasets/population/master/data/population.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   Country Name Country Code  Year  Value
# 0        Aruba          ABW  1960  54922
# 1        Aruba          ABW  1961  55578
# 2        Aruba          ABW  1962  56320
# 3        Aruba          ABW  1963  57002
# 4        Aruba          ABW  1964  57619

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')

# %%
df_2020 = df[df['Year'] == 2020]
df_2020.head()
# Out:
#                     Country Name Country Code  Year      Value
# 60                         Aruba          ABW  2020     108587
# 125  Africa Eastern and Southern          AFE  2020  694446100
# 190                  Afghanistan          AFG  2020   39068979
# 255   Africa Western and Central          AFW  2020  474569351
# 320                       Angola          AGO  2020   33451132

# %%
top10 = df_2020.sort_values(by='Value', ascending=False).head(10)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['Value'])
plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.show()

# %%
plt.hist(df_2020['Value'], bins=10)
plt.title("Population Distribution")
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.show()
